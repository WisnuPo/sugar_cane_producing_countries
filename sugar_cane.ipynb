# %%
# import library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.reset_option('max_columns')

# %%
# dataset calling
sugar_data = pd.read_csv("List of Countries by Sugarcane Production.csv")
sugar_data
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %%
# summary statistics
sugar_data.describe()
# Out:
#        Unnamed: 0
# count  103.000000
# mean    51.000000
# std     29.877528
# min      0.000000
# 25%     25.500000
# 50%     51.000000
# 75%     76.500000
# max    102.000000

# %%
# data types
sugar_data.dtypes
# Out:
# Unnamed: 0                     int64
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
sugar_data.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
# change the value of dataset
sugar_data['Production (Tons)'] = sugar_data['Production (Tons)'].str.replace('.', '')
sugar_data['Production per Person (Kg)'] = sugar_data['Production per Person (Kg)'].str.replace('.', '').str.replace(',', '.')
sugar_data['Acreage (Hectare)'] = sugar_data['Acreage (Hectare)'].str.replace('.', "")
sugar_data['Yield (Kg / Hectare)'] = sugar_data['Yield (Kg / Hectare)'].str.replace('.','').str.replace(',', '.')

sugar_data
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America         768678382
# 1             1      India           Asia         348448000
# 2             2      China           Asia         123059739
# 3             3   Thailand           Asia          87468496
# 4             4   Pakistan           Asia          65450704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                     3668.531          10226205              75167.5
# 1                       260721           4950000              70393.5
# ...

# %%
# see missing data
sugar_data.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
# drop missing data
sugar_data.dropna(inplace=True)

# %%
# check missing value again

sugar_data.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             0
# Yield (Kg / Hectare)          0
# dtype: int64

# %%
# delete unnecessary column
sugar_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
sugar_data
# Out:
#        Country      Continent Production (Tons) Production per Person (Kg)  \
# 0       Brazil  South America         768678382                   3668.531
# 1        India           Asia         348448000                     260721
# 2        China           Asia         123059739                      88287
# 3     Thailand           Asia          87468496                   1264.303
# 4     Pakistan           Asia          65450704                     324219
# ..         ...            ...               ...                        ...
# 97       Spain         Europe               394                          8
# 98     Lebanon           Asia                97                         16
# 100  Singapore           Asia                50                          9
# 101      Samoa        Oceania                12                          6
# 102      Syria           Asia                 1                          0
#
#     Acreage (Hectare) Yield (Kg / Hectare)
# ...

# %%
# change the data type
sugar_data['Production (Tons)']= sugar_data['Production (Tons)'].astype(float)
sugar_data['Production per Person (Kg)'] = sugar_data['Production per Person (Kg)'].astype(float)
sugar_data['Acreage (Hectare)'] = sugar_data['Acreage (Hectare)'].astype(float)
sugar_data['Yield (Kg / Hectare)'] = sugar_data['Yield (Kg / Hectare)'].astype(float)

# %%
# check data type

sugar_data.dtypes
# Out:
# Country                        object
# Continent                      object
# Production (Tons)             float64
# Production per Person (Kg)    float64
# Acreage (Hectare)             float64
# Yield (Kg / Hectare)          float64
# dtype: object

# %%
sugar_data.head(10)
# Out:
#                     Country      Continent  Production (Tons)  \
# 0                    Brazil  South America        768678382.0
# 1                     India           Asia        348448000.0
# 2                     China           Asia        123059739.0
# 3                  Thailand           Asia         87468496.0
# 4                  Pakistan           Asia         65450704.0
# 5                    Mexico  North America         56446821.0
# 6                  Colombia  South America         36951213.0
# 7                 Australia        Oceania         34403004.0
# 8                 Guatemala  North America         33533403.0
# 9  United States of America  North America         29926210.0
#
#    Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 0                    3668.531         10226205.0               75167.5
# 1                  260721.000          4950000.0               70393.5
# ...

# %%
# dataset summary

sugar_data.describe()
# Out:
#        Production (Tons)  Production per Person (Kg)  Acreage (Hectare)  \
# count       1.020000e+02                  102.000000       1.020000e+02
# mean        1.850372e+07               112952.435755       2.498981e+05
# std         8.419149e+07               176651.341929       1.137003e+06
# min         1.000000e+00                    0.000000       0.000000e+00
# 25%         6.251875e+04                 3671.910000       1.104000e+03
# 50%         1.440044e+06                25572.500000       1.655800e+04
# 75%         6.426824e+06               146384.750000       8.047400e+04
# max         7.686784e+08               951087.000000       1.022620e+07
#
#        Yield (Kg / Hectare)
# count            102.000000
# mean           52628.078431
# std            30504.676683
# min               10.000000
# 25%            29072.025000
# 50%            54108.950000
# 75%            73282.700000
# max           129049.300000

# %%
# continent

sugar_data['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
# make bar chart continent

continent = sugar_data['Continent'].value_counts()

# defining data
x_value = continent.index
y_value = continent

# make graph

plt.figure(figsize=(9,5))
plt.bar(x_value, y_value, width=0.5)
plt.title('Sugarcane Producing Countries by Continent', fontsize=16)
plt.xlabel('Continent')
plt.ylabel('Count')
plt.xticks(rotation=0)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Africa'),
#   Text(1, 0, 'Asia'),
#   Text(2, 0, 'North America'),
#   Text(3, 0, 'South America'),
#   Text(4, 0, 'Oceania'),
#   Text(5, 0, 'Europe')])

# %%
top20 = sugar_data.head(20)

# make bar chart continent

continent = top20['Continent'].value_counts()

# defining data
x_value = continent.index
y_value = continent

# make graph

plt.figure(figsize=(9,5))
plt.bar(x_value, y_value, width=0.5)
plt.title('Top 20 Sugarcane Producing Countries by Total Production', fontsize=16)
plt.xlabel('Continent')
plt.ylabel('Count')
plt.xticks(rotation=25)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Asia'),
#   Text(1, 0, 'South America'),
#   Text(2, 0, 'North America'),
#   Text(3, 0, 'Africa'),
#   Text(4, 0, 'Oceania')])

# %%
top20
# Out:
#                      Country      Continent  Production (Tons)  \
# 0                     Brazil  South America        768678382.0
# 1                      India           Asia        348448000.0
# 2                      China           Asia        123059739.0
# 3                   Thailand           Asia         87468496.0
# 4                   Pakistan           Asia         65450704.0
# 5                     Mexico  North America         56446821.0
# 6                   Colombia  South America         36951213.0
# 7                  Australia        Oceania         34403004.0
# 8                  Guatemala  North America         33533403.0
# 9   United States of America  North America         29926210.0
# 10                 Indonesia           Asia         27158830.0
# 11               Philippines           Asia         22370546.0
# 12                 Argentina  South America         21990823.0
# 13                      Cuba  North America         18890972.0
# ...

# %%
# sort asc production / person
sugarData = sugar_data.sort_values(by='Production per Person (Kg)', ascending=False)
sugDat = sugarData.head(5)

# %%
# make a pie chart
plt.figure(figsize=(9, 7))
plt.pie(sugDat['Production per Person (Kg)'], labels=sugDat['Country'], autopct='%1.1f%%')
plt.title('Sugarcane Producing Countries by Product/Person', fontsize=16)
plt.show()

# %%
sugar_data.head(5)
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %%
from sklearn.linear_model import LinearRegression

x = sugar_data['Acreage (Hectare)'].values
y = sugar_data['Production (Tons)'].values
x_reshape = x.reshape(-1, 1)

model = LinearRegression()

model.fit(x_reshape, y)

y_pred = model.predict(x_reshape)

plt.scatter(x_reshape, y, label='Data')
plt.plot(x_reshape, y_pred, color='red', label='Linear Regression')
plt.xlabel('Acreage')
plt.ylabel('Production')
plt.title('Linear Regression Acreage Production')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
